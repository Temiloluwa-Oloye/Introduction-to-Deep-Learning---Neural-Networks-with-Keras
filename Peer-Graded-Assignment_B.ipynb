# %% [markdown]
# # Build a Regression Model in Keras #

# %%
# import libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# import keras libraries
from keras.models import Sequential
from keras.layers import Dense

# %%
# download data
concrete_data = pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv')
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# # B. Normalize the data (5 marks) #
#
# Repeat Part A but use a normalized version of the data. Recall that one way to normalize the data is by subtracting the mean from the individual predictors and dividing by the standard deviation.

# %%
# normalize the data
concrete_data = (concrete_data - concrete_data.mean())/concrete_data.std()
concrete_data.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age  Strength
# 0          0.862735       -1.217079 -0.279597  2.644123
# 1          1.055651       -1.217079 -0.279597  1.560663
# 2         -0.526262       -2.239829  3.551340  0.266498
# 3         -0.526262       -2.239829  5.055221  0.313188
# 4          0.070492        0.647569  4.976069  0.507732

# %% [markdown]
# Repeat Part A

# %%
predictors = concrete_data.iloc[:,0:8]
predictors.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %%
target = concrete_data.iloc[:,8]
target.head()
# Out:
# 0    2.644123
# 1    1.560663
# 2    0.266498
# 3    0.313188
# 4    0.507732
# Name: Strength, dtype: float64

# %%
n_cols = predictors.shape[1]
n_cols
# Out:
# 8

# %%
# create a regression model function
def regression_model():
    # create model
    model = Sequential()
    model.add(Dense(10, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(1))
    
    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
import warnings

# Suppress all warnings
warnings.filterwarnings("ignore")

total_mse = 50
mse_list = []
epochs = 50

for i in range(total_mse):
    X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.3, random_state=42)
    model = regression_model()
    model.fit(X_train, y_train, epochs=epochs, verbose=0)
    y_pred = model.predict(X_test)
    mse_list.append(mean_squared_error(y_test, y_pred))
    print('MSE ' + str(i+1) + ' : ' + str(mse_list[i]))
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MSE 1 : 0.22584267295801194
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MSE 2 : 0.2287533060753249
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MSE 3 : 0.23625450816697474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# MSE 4 : 0.3295578824532289
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# MSE 5 : 0.3748274055676205
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# MSE 6 : 0.24683888597119655
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# MSE 7 : 0.24820698128978966
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MSE 8 : 0.24502069923530173
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# MSE 9 : 0.233771117850063
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MSE 10 : 0.19361890074700608
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# MSE 11 : 0.2351548264368777
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# MSE 12 : 0.25977250936580554
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# MSE 13 : 0.239506432385862
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# MSE 14 : 0.24411072437380296
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MSE 15 : 0.3015341841313171
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# MSE 16 : 0.23992901637456623
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# MSE 17 : 0.19487711696840082
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# MSE 18 : 0.43155727102339636
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# MSE 19 : 0.284387026826469
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# MSE 20 : 0.22387690075403702
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MSE 21 : 0.2607128763888531
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MSE 22 : 0.24165326304937434
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MSE 23 : 0.20365812187759585
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# MSE 24 : 0.27960241780079365
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# MSE 25 : 0.2495405882887
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# MSE 26 : 0.2074796633679422
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# MSE 27 : 0.3462947135378683
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MSE 28 : 0.22716081089026166
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MSE 29 : 0.2865547621458851
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MSE 30 : 0.24006059543734118
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# MSE 31 : 0.1950737625121609
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# MSE 32 : 0.24125988683271374
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MSE 33 : 0.21466692421964184
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MSE 34 : 0.2005089411450323
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MSE 35 : 0.22986058897141992
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# MSE 36 : 0.3223425123952946
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# MSE 37 : 0.2730716117859042
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# MSE 38 : 0.20854590661616298
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# MSE 39 : 0.2404904994242917
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MSE 40 : 0.23794240144809373
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MSE 41 : 0.21737916634846247
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# MSE 42 : 0.30989437634052824
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# MSE 43 : 0.2948202564473808
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# MSE 44 : 0.28056310231096443
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MSE 45 : 0.23730259311543833
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# MSE 46 : 0.2441792560807657
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MSE 47 : 0.24472327085424406
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MSE 48 : 0.25052077730385464
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# MSE 49 : 0.2368421213116389
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# MSE 50 : 0.22146317459598133

# %%
mean_of_mse = np.mean(mse_list)
std_of_mse = np.std(mse_list)

print('Mean of MSE : ' + str(mean_of_mse))
print('Standard Deviation of MSE : ' + str(std_of_mse))
# Out:
# Mean of MSE : 0.25323134623599286
# Standard Deviation of MSE : 0.046291544474728705

# %% [markdown]
# ## How does the mean of the mean squared errors compare to that from Step A? ##

# %% [markdown]
# The mean of the mean squared errors decreased significantly as compared to that from Step A. This implies that normalization helps to improve the accuracy of our trained model
