# %% [markdown]
# <a href="https://cognitiveclass.ai"><img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0101EN-SkillsNetwork/images/IDSN-logo.png" width="400"> </a>
#
# # Transformers with Keras
#
# Estimated time needed **45** mins

# %% [markdown]
# In this lab, we will learn how to use the Keras library to build a transformer using a sequence-to-sequence architecture with self-attention for translation. We will train the model using a sample dataset and then use this model for English to Spanish translation.

# %% [markdown]
# # Objectives for this Notebook
# * How to use the Keras library to build transformers model
# * Train the transformer model using a given dataset
# * Use the trained transformer model to translate

# %% [markdown]
# <h2>Table of Contents</h2>
#
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 4>
# 1. <a href="#Import-Keras-and-Packages">Import Keras and Packages</a><br>
# 2. <a href="#Step-1:-Data-Preparation">Step 1: Data Preparation</a><br>
# 3. <a href="#Step-2:-Self-Attention-Layer">Step 2: Self-Attention Layer</a><br>
# 4. <a href="#Step-3:-Model-Architecture">Step 3: Model Architecture</a><br>
# 5. <a href="#Step-4:-Training-the-Model">Step 4: Training the Model</a><br>
# 6. <a href="#Step-5:-Plotting-the-training-loss">Step 5: Plotting the training loss</a><br>
#
# </font>
# </div>

# %% [markdown]
# ## Import Keras and Packages

# %% [markdown]
# Let's start by importing the keras libraries and the packages that we would need to build a neural network.

# %% [markdown]
# The following required libraries are __not__ pre-installed in the Skills Network Labs environment. __You will need to run the following cell__ to install them:

# %%
# !pip install tensorflow==2.17.1
# !pip install matplotlib==3.9.2

print("==== All required libraries are installed =====")

# %% [markdown]
# #### Suppress the tensorflow warning messages
# We use the following code to  suppress the warning messages due to use of CPU architechture for tensoflow.
#
# You may want to **comment out** these lines if you are using the GPU architechture

# %%
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %% [markdown]
# ##### To use Keras, you will also need to install a backend framework – such as TensorFlow.
#
# If you install TensorFlow 2.16 or above, it will install Keras by default.
#
# We are using the CPU version of tensorflow since we are dealing with smaller datasets.
# You may install the GPU version of tensorflow on your machine to accelarate the processing of larger datasets

# %% [markdown]
# ### Import the necessary libraries

# %%
import numpy as np
from keras.models import Model
from keras.layers import Input, LSTM, Dense, Embedding, Dropout
from tensorflow.keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import backend as K
from keras.layers import Layer
import warnings
warnings.simplefilter('ignore', FutureWarning)
# Out:
# WARNING:tensorflow:From C:\Users\Temiloluwa Oloye\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # Step 1: Data Preparation
# We start by define the sentences and text for translation training
# Sentence Pairs: Defines a small dataset of English-Spanish sentence pairs.
# Target Sequences:
# Prepends "startseq" and appends "endseq" to each target sentence for the decoder to learn when to start and stop translating.

# %%
# Sample parallel sentences (English -> Spanish)
input_texts = [
    "Hello.", "How are you?", "I am learning machine translation.", "What is your name?", "I love programming."
]
target_texts = [
    "Hola.", "¿Cómo estás?", "Estoy aprendiendo traducción automática.", "¿Cuál es tu nombre?", "Me encanta programar."
]

target_texts = ["startseq " + x + " endseq" for x in target_texts]

# %% [markdown]
# ## Next, we convert the text from the sentences to tokens and create a vocabulary
# Tokenization: Uses Tokenizer to convert words into numerical sequences.

# %%
# Tokenization
input_tokenizer = Tokenizer()
input_tokenizer.fit_on_texts(input_texts)
input_sequences = input_tokenizer.texts_to_sequences(input_texts)

output_tokenizer = Tokenizer()
output_tokenizer.fit_on_texts(target_texts)
output_sequences = output_tokenizer.texts_to_sequences(target_texts)

input_vocab_size = len(input_tokenizer.word_index) + 1
output_vocab_size = len(output_tokenizer.word_index) + 1

# %% [markdown]
# ### Now pad the corresponding sentences
# Padding: Ensures all sequences have the same length.

# %%
# Padding
max_input_length = max([len(seq) for seq in input_sequences])
max_output_length = max([len(seq) for seq in output_sequences])

input_sequences = pad_sequences(input_sequences, maxlen=max_input_length, padding='post')
output_sequences = pad_sequences(output_sequences, maxlen=max_output_length, padding='post')

# %%
# Prepare the target data for training
decoder_input_data = output_sequences[:, :-1]
decoder_output_data = output_sequences[:, 1:]

# Convert to one-hot
decoder_output_data = np.array([np.eye(output_vocab_size)[seq] for seq in decoder_output_data])

# %% [markdown]
# # Step 2: Self-Attention Layer
# Self-attention is a mechanism that allows a model to **focus on relevant parts of the input sequence** while processing each word. This is particularly useful in:
# 1) Machine Translation (e.g., aligning words correctly)
# 2) Text Summarization
# 3) Speech Recognition
# 4) Image Processing (Vision Transformers)
# In this implementation, self-attention is used for text based sequence-to-sequence modeling.
#
#
# Self-Attention works for a given an input sequence by computing a weighted representation of all words for each position. It does so using three key components:
#
# 1. Query **(Q)**, Key **(K)**, and Value **(V)** Matrices
# For each word (token) in a sequence:
#
# Query (Q): What this word is looking for.
# Key (K): What this word represents.
# Value (V): The actual information in the word.
#
# 2. Compute **Attention Scores**
# Next, we **calculate the similarity between each query and key** using dot-product attention:
# Each word in a sequence attends to every other word based on these scores.
#
# 3. Apply **Scaling & Softmax**
# Since dot-product values can be large, we scale them.
# Next, Applying softmax converts scores into attention weights:

# %% [markdown]
# ### Self-Attention class
# In this implementation of self-attention layer:
# 1. We first initialize the weights in the **build** method, where:
#     1. **self.Wq**, **self.Wk**, **self.Wv** are the trainable weight matrices.
#     2. Their **shape is (feature_dim, feature_dim)**, meaning they transform input features into Q, K, and V representations.
# 2. Applying Attention using **call** method. The **call()** method:
#    1. Computes **Q, K, V** by multiplying inputs (encoder/decoder output) with their respective weight matrices.
#    2. Computes **dot-product attention scores** using K.batch_dot(q, k, axes=[2, 2]), resulting in a (batch_size, seq_len, seq_len) matrix.
#    3. **Scales** the scores to avoid large values.
#    4. Applies **softmax** to normalize the attention scores.
#    5. **Multiplies attention weights with V** to get the final output.
# 3. The **compute_output_shape** method defines the shape of the output tensor after the layer processes an input.
#     1. The output shape of the Self-Attention layer **remains the same** as the input shape.
#     2. The attention mechanism **transforms** the input but does not change its dimensions.4
#     3. If the attention layer changed the shape, you would modify compute_output_shape

# %%
# Define the Self-Attention Layer
class SelfAttention(Layer):
    def __init__(self, **kwargs):
        super(SelfAttention, self).__init__(**kwargs)

    def build(self, input_shape):
        feature_dim = input_shape[-1]
        # Weight matrices for Q, K, V
        self.Wq = self.add_weight(shape=(feature_dim, feature_dim), 
                                  initializer='glorot_uniform', 
                                  trainable=True, 
                                  name='Wq')
        self.Wk = self.add_weight(shape=(feature_dim, feature_dim), 
                                  initializer='glorot_uniform', 
                                  trainable=True, 
                                  name='Wk')
        self.Wv = self.add_weight(shape=(feature_dim, feature_dim), 
                                  initializer='glorot_uniform', 
                                  trainable=True, 
                                  name='Wv')
        super(SelfAttention, self).build(input_shape)

    def call(self, inputs):
        # Linear projections
        q = K.dot(inputs, self.Wq)  # Query
        k = K.dot(inputs, self.Wk)  # Key
        v = K.dot(inputs, self.Wv)  # Value

        # Scaled Dot-Product Attention
        scores = K.batch_dot(q, k, axes=[2, 2])  # (batch, seq_len, seq_len)
        scores = scores / K.sqrt(K.cast(K.shape(k)[-1], dtype=K.floatx()))  # Scale
        attention_weights = K.softmax(scores, axis=-1)  # Normalize

        # Weighted sum of values
        output = K.batch_dot(attention_weights, v)  # (batch, seq_len, feature_dim)
        return output

    def compute_output_shape(self, input_shape):
        return input_shape

# %% [markdown]
# # Step 3: Model Architecture
# The model follows an Encoder-Decoder structure:
#
# ### Encoder:
# 1) Takes input sentences (padded and tokenized).
# 2) Uses an Embedding layer (word representations) + LSTM (to process sequences).
#     1. The LSTMs are used as the **help process variable-length input sentences** and generate meaningful translations.
# 4) Outputs context vectors (hidden & cell states).
#
# ### Attention Layer
# 1) Applied to both the encoder and decoder outputs.
# 2) Helps the decoder focus on relevant words during translation.
#
# ### Decoder
# 1) Receives target sequences (shifted one step ahead).
# 2) Uses an LSTM with encoder states as initial states.
# 3) Applies self-attention for better learning.
# 4) Uses a Dense layer (Softmax) to predict the next word.

# %%
from tensorflow.keras.layers import AdditiveAttention, Concatenate, Dense, Embedding, Input, LSTM
from tensorflow.keras.models import Model
 
# Encoder
encoder_inputs = Input(shape=(max_input_length,))
encoder_embedding = Embedding(input_vocab_size, 256)(encoder_inputs)
encoder_lstm = LSTM(256, return_sequences=True, return_state=True)
encoder_outputs, state_h, state_c = encoder_lstm(encoder_embedding)
encoder_states = [state_h, state_c]
 
# Decoder
decoder_inputs = Input(shape=(max_output_length - 1,))
decoder_embedding = Embedding(output_vocab_size, 256)(decoder_inputs)
decoder_lstm = LSTM(256, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_embedding, initial_state=encoder_states)
 
# Attention: decoder attends to encoder outputs
attention = AdditiveAttention()
attention_output = attention([decoder_outputs, encoder_outputs])
 
# Combine decoder outputs with attention context
decoder_concat = Concatenate(axis=-1)([decoder_outputs, attention_output])
 
# Final Dense layer
decoder_dense = Dense(output_vocab_size, activation='softmax')
decoder_outputs = decoder_dense(decoder_concat)
 
# Full Model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
 
# Summary
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\Temiloluwa Oloye\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\Temiloluwa Oloye\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 5)]                  0         []
#
#  input_2 (InputLayer)        [(None, 5)]                  0         []
#
#  embedding (Embedding)       (None, 5, 256)               4096      ['input_1[0][0]']
#
#  embedding_1 (Embedding)     (None, 5, 256)               4352      ['input_2[0][0]']
#
#  lstm (LSTM)                 [(None, 5, 256),             525312    ['embedding[0][0]']
#                               (None, 256),
#                               (None, 256)]
#
#  lstm_1 (LSTM)               [(None, 5, 256),             525312    ['embedding_1[0][0]',
#                               (None, 256),                           'lstm[0][1]',
#                               (None, 256)]                           'lstm[0][2]']
#
#  additive_attention (Additi  (None, 5, 256)               256       ['lstm_1[0][0]',
#  veAttention)                                                        'lstm[0][0]']
#
#  concatenate (Concatenate)   (None, 5, 512)               0         ['lstm_1[0][0]',
#                                                                      'additive_attention[0][0]']
#
#  dense (Dense)               (None, 5, 17)                8721      ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 1068049 (4.07 MB)
# Trainable params: 1068049 (4.07 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# # Step 4: Training the Model
# Uses categorical_crossentropy as the loss function since output words are one-hot encoded.
# Trains using Adam optimizer for 100 epochs.

# %%
# Step 6: Train the Model
history_glorot_adam = model.fit([input_sequences, decoder_input_data], decoder_output_data, epochs=100, batch_size=16)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\Temiloluwa Oloye\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Temiloluwa Oloye\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 1/1 [==============================] - 3s 3s/step - loss: 2.8311 - accuracy: 0.1600
# Epoch 2/100
# 1/1 [==============================] - 0s 16ms/step - loss: 2.7990 - accuracy: 0.5200
# Epoch 3/100
# 1/1 [==============================] - 0s 18ms/step - loss: 2.7655 - accuracy: 0.3200
# Epoch 4/100
# 1/1 [==============================] - 0s 17ms/step - loss: 2.7277 - accuracy: 0.3200
# Epoch 5/100
# 1/1 [==============================] - 0s 18ms/step - loss: 2.6824 - accuracy: 0.3200
# Epoch 6/100
# 1/1 [==============================] - 0s 16ms/step - loss: 2.6256 - accuracy: 0.3200
# Epoch 7/100
# 1/1 [==============================] - 0s 16ms/step - loss: 2.5524 - accuracy: 0.3200
# Epoch 8/100
# 1/1 [==============================] - 0s 18ms/step - loss: 2.4571 - accuracy: 0.2800
# Epoch 9/100
# 1/1 [==============================] - 0s 14ms/step - loss: 2.3363 - accuracy: 0.2400
# Epoch 10/100
# 1/1 [==============================] - 0s 15ms/step - loss: 2.2010 - accuracy: 0.2400
# Epoch 11/100
# 1/1 [==============================] - 0s 15ms/step - loss: 2.0975 - accuracy: 0.2400
# Epoch 12/100
# 1/1 [==============================] - 0s 14ms/step - loss: 2.0732 - accuracy: 0.2400
# Epoch 13/100
# 1/1 [==============================] - 0s 16ms/step - loss: 2.0533 - accuracy: 0.2400
# Epoch 14/100
# 1/1 [==============================] - 0s 15ms/step - loss: 1.9847 - accuracy: 0.2800
# Epoch 15/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.9012 - accuracy: 0.3200
# Epoch 16/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.8469 - accuracy: 0.3600
# Epoch 17/100
# 1/1 [==============================] - 0s 15ms/step - loss: 1.8230 - accuracy: 0.4400
# Epoch 18/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.7880 - accuracy: 0.4400
# Epoch 19/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.7312 - accuracy: 0.4400
# Epoch 20/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.6646 - accuracy: 0.4800
# Epoch 21/100
# 1/1 [==============================] - 0s 16ms/step - loss: 1.5993 - accuracy: 0.5200
# Epoch 22/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.5401 - accuracy: 0.4800
# Epoch 23/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.4868 - accuracy: 0.4800
# Epoch 24/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.4363 - accuracy: 0.4800
# Epoch 25/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.3825 - accuracy: 0.4400
# Epoch 26/100
# 1/1 [==============================] - 0s 11ms/step - loss: 1.3197 - accuracy: 0.4800
# Epoch 27/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.2469 - accuracy: 0.5200
# Epoch 28/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.1695 - accuracy: 0.5600
# Epoch 29/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.0944 - accuracy: 0.6400
# Epoch 30/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.0239 - accuracy: 0.6800
# Epoch 31/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.9565 - accuracy: 0.7600
# Epoch 32/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.8934 - accuracy: 0.7600
# Epoch 33/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.8359 - accuracy: 0.7200
# Epoch 34/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.7791 - accuracy: 0.7600
# Epoch 35/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.7226 - accuracy: 0.7600
# Epoch 36/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6695 - accuracy: 0.8400
# Epoch 37/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6178 - accuracy: 0.8400
# Epoch 38/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5684 - accuracy: 0.9200
# Epoch 39/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5242 - accuracy: 0.9600
# Epoch 40/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.4839 - accuracy: 1.0000
# Epoch 41/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.4446 - accuracy: 1.0000
# Epoch 42/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.4084 - accuracy: 1.0000
# Epoch 43/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.3769 - accuracy: 1.0000
# Epoch 44/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.3470 - accuracy: 1.0000
# Epoch 45/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3188 - accuracy: 1.0000
# Epoch 46/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2929 - accuracy: 1.0000
# Epoch 47/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2694 - accuracy: 1.0000
# Epoch 48/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2463 - accuracy: 1.0000
# Epoch 49/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2242 - accuracy: 1.0000
# Epoch 50/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.2051 - accuracy: 1.0000
# Epoch 51/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1877 - accuracy: 1.0000
# Epoch 52/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1730 - accuracy: 1.0000
# Epoch 53/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1592 - accuracy: 1.0000
# Epoch 54/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1450 - accuracy: 1.0000
# Epoch 55/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1314 - accuracy: 1.0000
# Epoch 56/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1198 - accuracy: 1.0000
# Epoch 57/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1098 - accuracy: 1.0000
# Epoch 58/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1007 - accuracy: 1.0000
# Epoch 59/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0928 - accuracy: 1.0000
# Epoch 60/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0852 - accuracy: 1.0000
# Epoch 61/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0782 - accuracy: 1.0000
# Epoch 62/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0718 - accuracy: 1.0000
# Epoch 63/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0660 - accuracy: 1.0000
# Epoch 64/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0606 - accuracy: 1.0000
# Epoch 65/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0560 - accuracy: 1.0000
# Epoch 66/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0519 - accuracy: 1.0000
# Epoch 67/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0480 - accuracy: 1.0000
# Epoch 68/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0444 - accuracy: 1.0000
# Epoch 69/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0412 - accuracy: 1.0000
# Epoch 70/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0383 - accuracy: 1.0000
# Epoch 71/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0356 - accuracy: 1.0000
# Epoch 72/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0332 - accuracy: 1.0000
# Epoch 73/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0310 - accuracy: 1.0000
# Epoch 74/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0290 - accuracy: 1.0000
# Epoch 75/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0271 - accuracy: 1.0000
# Epoch 76/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0254 - accuracy: 1.0000
# Epoch 77/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0240 - accuracy: 1.0000
# Epoch 78/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0226 - accuracy: 1.0000
# Epoch 79/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0214 - accuracy: 1.0000
# Epoch 80/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0202 - accuracy: 1.0000
# Epoch 81/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0191 - accuracy: 1.0000
# Epoch 82/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 83/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 84/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 85/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 86/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0148 - accuracy: 1.0000
# Epoch 87/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 88/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 89/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 90/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 91/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 92/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 93/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 94/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 95/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 96/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 97/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 98/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 99/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 100/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0086 - accuracy: 1.0000

# %% [markdown]
# # Step 5: Plotting the training loss

# %%
# Plotting training loss
import matplotlib.pyplot as plt
plt.plot(history_glorot_adam.history['loss'])
plt.title('Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# # Awesome, now you have succesfully trained a transformers model.
# ### Now let's try some practice excercises

# %% [markdown]
# ## Practice excercise 1

# %% [markdown]
# In this practice exercise, let's train the model using "he_uniform" initializer instead of "glorot_uniform". Then, compare the training loss between model using "glorot_uniform" vs "he_uniform" initializers by plotting them using matplotlib

# %%
## Write your answer here
#Define the Self-Attention Layer
class SelfAttention(Layer):
    def __init__(self, **kwargs):
        super(SelfAttention, self).__init__(**kwargs)

    def build(self, input_shape):
        feature_dim = input_shape[-1]
        # Weight matrices for Q, K, V
        self.Wq = self.add_weight(shape=(feature_dim, feature_dim), 
                                  initializer='he_uniform', 
                                  trainable=True, 
                                  name='Wq')
        self.Wk = self.add_weight(shape=(feature_dim, feature_dim), 
                                  initializer='he_uniform', 
                                  trainable=True, 
                                  name='Wk')
        self.Wv = self.add_weight(shape=(feature_dim, feature_dim), 
                                  initializer='he_uniform', 
                                  trainable=True, 
                                  name='Wv')
        super(SelfAttention, self).build(input_shape)

    def call(self, inputs):
        # Linear projections
        q = K.dot(inputs, self.Wq)  # Query
        k = K.dot(inputs, self.Wk)  # Key
        v = K.dot(inputs, self.Wv)  # Value

        # Scaled Dot-Product Attention
        scores = K.batch_dot(q, k, axes=[2, 2])  # (batch, seq_len, seq_len)
        scores = scores / K.sqrt(K.cast(K.shape(k)[-1], dtype=K.floatx()))  # Scale
        attention_weights = K.softmax(scores, axis=-1)  # Normalize

        # Weighted sum of values
        output = K.batch_dot(attention_weights, v)  # (batch, seq_len, feature_dim)
        return output

    def compute_output_shape(self, input_shape):
        return input_shape

    
#Encoder
encoder_inputs = Input(shape=(max_input_length,))
encoder_embedding = Embedding(input_vocab_size, 256)(encoder_inputs)
encoder_lstm = LSTM(256, return_sequences=True, return_state=True)
encoder_outputs, state_h, state_c = encoder_lstm(encoder_embedding)
encoder_states = [state_h, state_c]

#Decoder
decoder_inputs = Input(shape=(max_output_length - 1,), name="decoder_inputs")
decoder_embedding = Embedding(output_vocab_size, 256, name="decoder_embedding")(decoder_inputs)
decoder_lstm = LSTM(256, return_sequences=True, return_state=True, name="decoder_lstm")
decoder_outputs, _, _ = decoder_lstm(decoder_embedding, initial_state=encoder_states)

#Attention Mechanism
attention = AdditiveAttention(name="attention_layer")
attention_output = attention([decoder_outputs, encoder_outputs])

# Concatenate context with decoder outputs
decoder_concat = Concatenate(axis=-1, name="concat_layer")([decoder_outputs, attention_output])

# Final Dense Layer
decoder_dense = Dense(output_vocab_size, activation='softmax', name="output_dense")
decoder_outputs = decoder_dense(decoder_concat)

#Full Model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])


#Step 6: Train the Model
history_he = model.fit([input_sequences, decoder_input_data], decoder_output_data, epochs=100, batch_size=16)

#Plotting training losses for glorot_uniform and he_uniform inititalizers
import matplotlib.pyplot as plt
plt.plot(history_glorot_adam.history['loss'], label="glorot_uniform", color='red')
plt.plot(history_he.history['loss'], label="he_uniform", color='blue')
plt.title('Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.8345 - accuracy: 0.0000e+00
# Epoch 2/100
# 1/1 [==============================] - 0s 15ms/step - loss: 2.8037 - accuracy: 0.3600
# Epoch 3/100
# 1/1 [==============================] - 0s 18ms/step - loss: 2.7714 - accuracy: 0.3200
# Epoch 4/100
# 1/1 [==============================] - 0s 16ms/step - loss: 2.7349 - accuracy: 0.3200
# Epoch 5/100
# 1/1 [==============================] - 0s 15ms/step - loss: 2.6910 - accuracy: 0.3200
# Epoch 6/100
# 1/1 [==============================] - 0s 14ms/step - loss: 2.6359 - accuracy: 0.3200
# Epoch 7/100
# 1/1 [==============================] - 0s 14ms/step - loss: 2.5646 - accuracy: 0.2800
# Epoch 8/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.4712 - accuracy: 0.2800
# Epoch 9/100
# 1/1 [==============================] - 0s 15ms/step - loss: 2.3515 - accuracy: 0.2800
# Epoch 10/100
# 1/1 [==============================] - 0s 16ms/step - loss: 2.2140 - accuracy: 0.2400
# Epoch 11/100
# 1/1 [==============================] - 0s 14ms/step - loss: 2.1019 - accuracy: 0.2400
# Epoch 12/100
# 1/1 [==============================] - 0s 17ms/step - loss: 2.0730 - accuracy: 0.2400
# Epoch 13/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.0706 - accuracy: 0.2400
# Epoch 14/100
# 1/1 [==============================] - 0s 14ms/step - loss: 2.0198 - accuracy: 0.2800
# Epoch 15/100
# 1/1 [==============================] - 0s 15ms/step - loss: 1.9404 - accuracy: 0.2800
# Epoch 16/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.8722 - accuracy: 0.3200
# Epoch 17/100
# 1/1 [==============================] - 0s 15ms/step - loss: 1.8331 - accuracy: 0.4800
# Epoch 18/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.8059 - accuracy: 0.5200
# Epoch 19/100
# 1/1 [==============================] - 0s 15ms/step - loss: 1.7665 - accuracy: 0.4800
# Epoch 20/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.7106 - accuracy: 0.4800
# Epoch 21/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.6450 - accuracy: 0.5200
# Epoch 22/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.5783 - accuracy: 0.4800
# Epoch 23/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.5166 - accuracy: 0.5200
# Epoch 24/100
# 1/1 [==============================] - 0s 17ms/step - loss: 1.4615 - accuracy: 0.5200
# Epoch 25/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.4078 - accuracy: 0.5200
# Epoch 26/100
# 1/1 [==============================] - 0s 19ms/step - loss: 1.3479 - accuracy: 0.5200
# Epoch 27/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.2811 - accuracy: 0.5200
# Epoch 28/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.2119 - accuracy: 0.6000
# Epoch 29/100
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1429 - accuracy: 0.6000
# Epoch 30/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0749 - accuracy: 0.6800
# Epoch 31/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1.0077 - accuracy: 0.7200
# Epoch 32/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.9433 - accuracy: 0.6800
# Epoch 33/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.8856 - accuracy: 0.6800
# Epoch 34/100
# 1/1 [==============================] - 0s 18ms/step - loss: 0.8281 - accuracy: 0.8000
# Epoch 35/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.7697 - accuracy: 0.8400
# Epoch 36/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.7208 - accuracy: 0.8800
# Epoch 37/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6739 - accuracy: 0.8400
# Epoch 38/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6239 - accuracy: 0.9600
# Epoch 39/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5797 - accuracy: 1.0000
# Epoch 40/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5360 - accuracy: 1.0000
# Epoch 41/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4933 - accuracy: 1.0000
# Epoch 42/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.4561 - accuracy: 1.0000
# Epoch 43/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.4170 - accuracy: 1.0000
# Epoch 44/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.3798 - accuracy: 1.0000
# Epoch 45/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.3492 - accuracy: 1.0000
# Epoch 46/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.3186 - accuracy: 1.0000
# Epoch 47/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2901 - accuracy: 1.0000
# Epoch 48/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2658 - accuracy: 1.0000
# Epoch 49/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2425 - accuracy: 1.0000
# Epoch 50/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2220 - accuracy: 1.0000
# Epoch 51/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2022 - accuracy: 1.0000
# Epoch 52/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1856 - accuracy: 1.0000
# Epoch 53/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1707 - accuracy: 1.0000
# Epoch 54/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1548 - accuracy: 1.0000
# Epoch 55/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1421 - accuracy: 1.0000
# Epoch 56/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1300 - accuracy: 1.0000
# Epoch 57/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1192 - accuracy: 1.0000
# Epoch 58/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1086 - accuracy: 1.0000
# Epoch 59/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1001 - accuracy: 1.0000
# Epoch 60/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0921 - accuracy: 1.0000
# Epoch 61/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0844 - accuracy: 1.0000
# Epoch 62/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0782 - accuracy: 1.0000
# Epoch 63/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0720 - accuracy: 1.0000
# Epoch 64/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0666 - accuracy: 1.0000
# Epoch 65/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0616 - accuracy: 1.0000
# Epoch 66/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0574 - accuracy: 1.0000
# Epoch 67/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0534 - accuracy: 1.0000
# Epoch 68/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0494 - accuracy: 1.0000
# Epoch 69/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0461 - accuracy: 1.0000
# Epoch 70/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0430 - accuracy: 1.0000
# Epoch 71/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0402 - accuracy: 1.0000
# Epoch 72/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0376 - accuracy: 1.0000
# Epoch 73/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0352 - accuracy: 1.0000
# Epoch 74/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0332 - accuracy: 1.0000
# Epoch 75/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0311 - accuracy: 1.0000
# Epoch 76/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0292 - accuracy: 1.0000
# Epoch 77/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0276 - accuracy: 1.0000
# Epoch 78/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0261 - accuracy: 1.0000
# Epoch 79/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0247 - accuracy: 1.0000
# Epoch 80/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0233 - accuracy: 1.0000
# Epoch 81/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0221 - accuracy: 1.0000
# Epoch 82/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0209 - accuracy: 1.0000
# Epoch 83/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0199 - accuracy: 1.0000
# Epoch 84/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0189 - accuracy: 1.0000
# Epoch 85/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 86/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0172 - accuracy: 1.0000
# Epoch 87/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0164 - accuracy: 1.0000
# Epoch 88/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 89/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 90/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0143 - accuracy: 1.0000
# Epoch 91/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 92/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 93/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 94/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 95/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 96/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 97/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 98/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 99/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 100/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0099 - accuracy: 1.0000

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- Your answer is below:
#
#
# #Define the Self-Attention Layer
# class SelfAttention(Layer):
#     def __init__(self, **kwargs):
#         super(SelfAttention, self).__init__(**kwargs)
#
#     def build(self, input_shape):
#         feature_dim = input_shape[-1]
#         # Weight matrices for Q, K, V
#         self.Wq = self.add_weight(shape=(feature_dim, feature_dim),
#                                   initializer='he_uniform',
#                                   trainable=True,
#                                   name='Wq')
#         self.Wk = self.add_weight(shape=(feature_dim, feature_dim),
#                                   initializer='he_uniform',
#                                   trainable=True,
#                                   name='Wk')
#         self.Wv = self.add_weight(shape=(feature_dim, feature_dim),
#                                   initializer='he_uniform',
#                                   trainable=True,
#                                   name='Wv')
#         super(SelfAttention, self).build(input_shape)
#
#     def call(self, inputs):
#         # Linear projections
#         q = K.dot(inputs, self.Wq)  # Query
#         k = K.dot(inputs, self.Wk)  # Key
#         v = K.dot(inputs, self.Wv)  # Value
#
#         # Scaled Dot-Product Attention
#         scores = K.batch_dot(q, k, axes=[2, 2])  # (batch, seq_len, seq_len)
#         scores = scores / K.sqrt(K.cast(K.shape(k)[-1], dtype=K.floatx()))  # Scale
#         attention_weights = K.softmax(scores, axis=-1)  # Normalize
#
#         # Weighted sum of values
#         output = K.batch_dot(attention_weights, v)  # (batch, seq_len, feature_dim)
#         return output
#
#     def compute_output_shape(self, input_shape):
#         return input_shape
#
#
# #Encoder
# encoder_inputs = Input(shape=(max_input_length,))
# encoder_embedding = Embedding(input_vocab_size, 256)(encoder_inputs)
# encoder_lstm = LSTM(256, return_sequences=True, return_state=True)
# encoder_outputs, state_h, state_c = encoder_lstm(encoder_embedding)
# encoder_states = [state_h, state_c]
#
# #Decoder
# decoder_inputs = Input(shape=(max_output_length - 1,), name="decoder_inputs")
# decoder_embedding = Embedding(output_vocab_size, 256, name="decoder_embedding")(decoder_inputs)
# decoder_lstm = LSTM(256, return_sequences=True, return_state=True, name="decoder_lstm")
# decoder_outputs, _, _ = decoder_lstm(decoder_embedding, initial_state=encoder_states)
#
# #Attention Mechanism
# attention = AdditiveAttention(name="attention_layer")
# attention_output = attention([decoder_outputs, encoder_outputs])
#
# # Concatenate context with decoder outputs
# decoder_concat = Concatenate(axis=-1, name="concat_layer")([decoder_outputs, attention_output])
#
# # Final Dense Layer
# decoder_dense = Dense(output_vocab_size, activation='softmax', name="output_dense")
# decoder_outputs = decoder_dense(decoder_concat)
#
# #Full Model
# model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
#
#
# #Step 6: Train the Model
# history_he = model.fit([input_sequences, decoder_input_data], decoder_output_data, epochs=100, batch_size=16)
#
# #Plotting training losses for glorot_uniform and he_uniform inititalizers
# import matplotlib.pyplot as plt
# plt.plot(history_glorot_adam.history['loss'], label="glorot_uniform", color='red')
# plt.plot(history_he.history['loss'], label="he_uniform", color='blue')
# plt.title('Training Loss')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()
#
#
# -->

# %% [markdown]
# ## Practice excercise 2

# %% [markdown]
# In this practice exercise, try to use adaptive gradient optimizer instead of adam. Then, plot and compare the results between adam and adaptive gradient optimizers

# %%
### Write your answer here
#Full Model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.compile(optimizer='adagrad', loss='categorical_crossentropy', metrics=['accuracy'])


#Step 6: Train the Model
history_adagrad = model.fit([input_sequences, decoder_input_data], decoder_output_data, epochs=100, batch_size=16)

#Plotting training losses for glorot_uniform and he_uniform inititalizers
import matplotlib.pyplot as plt
plt.plot(history_glorot_adam.history['loss'], label="adam", color='red')
plt.plot(history_adagrad.history['loss'], label="adagrad", color='blue')
plt.title('Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 2/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 3/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 4/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 5/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 6/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 7/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 8/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 9/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 10/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 11/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 12/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 13/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 14/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 15/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 16/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 17/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 18/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 19/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 20/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 21/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 22/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 23/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 24/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 25/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 26/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 27/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 28/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 29/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 30/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 31/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 32/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 33/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 34/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 35/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 36/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 37/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 38/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 39/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 40/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 41/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 42/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 43/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 44/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 45/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 46/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 47/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 48/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 49/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 50/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 51/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 52/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 53/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 54/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 55/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 56/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 57/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 58/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 59/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 60/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 61/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 62/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 63/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 64/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 65/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 66/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 67/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 68/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 69/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 70/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 71/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 72/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 73/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 74/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 75/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 76/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 77/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 78/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 79/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 80/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 81/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 82/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 83/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 84/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 85/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 86/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 87/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 88/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 89/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 90/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 91/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 92/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 93/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 94/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 95/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 96/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 97/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 98/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 99/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 100/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0095 - accuracy: 1.0000

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- Your answer is below:
#
# #Full Model
# model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
# model.compile(optimizer='adagrad', loss='categorical_crossentropy', metrics=['accuracy'])
#
#
# #Step 6: Train the Model
# history_adagrad = model.fit([input_sequences, decoder_input_data], decoder_output_data, epochs=100, batch_size=16)
#
# #Plotting training losses for glorot_uniform and he_uniform inititalizers
# import matplotlib.pyplot as plt
# plt.plot(history_glorot_adam.history['loss'], label="adam", color='red')
# plt.plot(history_adagrad.history['loss'], label="adagrad", color='blue')
# plt.title('Training Loss')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()
# -->

# %% [markdown]
# ## Thank you for completing this lab!
#
# This notebook was created by [Aman Aggarwal](https://www.linkedin.com/in/aggarwal-aman/). I hope you found this lab interesting and educational. Feel free to contact me if you have any questions!

# %% [markdown]
# <!--
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2024-11-20  | 1.0  | Aman  |  Created the lab |
# <hr>
# -->
# ## <h3 align="center"> © IBM Corporation. All rights reserved. <h3/>
